-- %%
GRANT SELECT ON TABLE catalog_dev.golden.clasificacion_vehiculo TO `Lideres`;
GRANT SELECT ON TABLE catalog_dev.golden.ranking_lideres TO `Lideres`;
GRANT SELECT ON TABLE catalog_dev.golden.tendencia_diaria TO `Lideres`;
GRANT SELECT ON TABLE catalog_dev.golden.zona_estado TO `Lideres`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `Developers`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `Developers`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
