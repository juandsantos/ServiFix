# %%
# %sql
REVOKE SELECT ON TABLE catalog_dev.golden.clasificacion_vehiculo FROM `Lideres`;
REVOKE SELECT ON TABLE catalog_dev.golden.ranking_lideres FROM `Lideres`;
REVOKE SELECT ON TABLE catalog_dev.golden.tendencia_diaria FROM `Lideres`;
REVOKE SELECT ON TABLE catalog_dev.golden.zona_estado FROM `Lideres`;

# %%
# %sql
REVOKE USE SCHEMA ON SCHEMA catalog_dev.bronze FROM `Developers`;
REVOKE CREATE ON SCHEMA catalog_dev.bronze FROM `Developers`;
