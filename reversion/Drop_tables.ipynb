# %%
# %sql
-- DROP TABLES bronze
DROP TABLE IF EXISTS catalog_dev.bronze.bitacora_incidentes;
DROP TABLE IF EXISTS catalog_dev.bronze.maestro_horas;

-- DROP TABLE silver
DROP TABLE IF EXISTS catalog_dev.silver.bitacora_clasificacion;

-- DROP TABLES golden
DROP TABLE IF EXISTS catalog_dev.golden.clasificacion_vehiculo;
DROP TABLE IF EXISTS catalog_dev.golden.ranking_lideres;
DROP TABLE IF EXISTS catalog_dev.golden.tendencia_diaria;
DROP TABLE IF EXISTS catalog_dev.golden.zona_estado;
